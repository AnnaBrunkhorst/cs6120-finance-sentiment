# %%
import numpy as np
import pandas as pd
import torch.nn as nn
from sklearn.metrics import classification_report, accuracy_score
from torch.optim.lr_scheduler import StepLR

from utils.DataUtils import DataUtils
from utils.GloveUtils import GloveUtils

# %%
# Load split data
train_df = pd.read_csv("./data/alpha_vantage_train.csv")
test_df = pd.read_csv("./data/alpha_vantage_test.csv")

# Initialize custom util library
utils = DataUtils()

# %% [markdown]
# Parse, tokenize, and lemmatize

# %%
train_df['clean_txt'] = utils.clean_data(train_df['text'], max_words=64)
test_df['clean_txt'] = utils.clean_data(test_df['text'], max_words=64)

# %%
GLOVE_PATH = "./data/glove.6B.100d.txt"
glove_utils = GloveUtils(GLOVE_PATH, max_dims=64)

glove_emb_layer = glove_utils.create_glove_emb_layer(trainable=True)
train_emb_ids = glove_utils.get_embedding_indices(train_df['clean_txt'])
test_emb_ids = glove_utils.get_embedding_indices(test_df['clean_txt'])
# Out:
# Glove Embedding shape: (400000, 100)

# %%
import torch

print(f'CUDA: {torch.cuda.is_available()}')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'DEVICE: {device}')
torch.cuda.empty_cache()
# Out:
# CUDA: True
# DEVICE: cuda:0

# %%
train_emb_ids = train_emb_ids.to(device)
test_emb_ids = test_emb_ids.to(device)

y_train = torch.Tensor(np.asarray(train_df['label'], dtype=np.uint8)).to(device)
y_test = torch.Tensor(np.asarray(test_df['label'], dtype=np.uint8)).to(device)

# %%
print(f'X: {train_emb_ids.shape}')
print(f'y: {y_train.shape}')
# Out:
# X: torch.Size([16688, 64])
# y: torch.Size([16688])

# %%
# Finally Embedding layer to the GPU
glove_emb_layer = glove_emb_layer.to(device)

_, cts = np.unique(torch.Tensor.cpu(y_train), return_counts=True)
class_weights = 1.0 / cts
class_weights /= class_weights.sum()
print(class_weights)
class_weights = torch.Tensor(class_weights).to(device)
# Out:
# [0.72971709 0.07080244 0.02451165 0.02927339 0.14569543]

# %%
BATCH_SIZE = 8192
NUM_LABELS = 5
MAX_WORDS = 64

def setup_model(num_classes=NUM_LABELS, emb_layer=glove_emb_layer):
    return nn.Sequential(
        emb_layer,
        nn.Flatten(),
        nn.Linear(64 * 100, 2048),
        nn.Dropout(0.3),
        nn.LeakyReLU(),
        nn.Linear(2048, 512),
        nn.Dropout(0.3),
        nn.LeakyReLU(),
        nn.Linear(512, 64),
        nn.LeakyReLU(),
        nn.Linear(64, num_classes),
        nn.Softmax(dim=1)
    )

# %%
def train_model(model, X_train, X_test, y_train, y_test, n_epochs=50, lr=0.001):
    loss_fn = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = StepLR(optimizer, step_size=100, gamma=0.1)
    batch_per_epoch = len(X_train) // BATCH_SIZE

    tr_loss_hist = np.zeros((n_epochs,), dtype=np.float32)
    ts_loss_hist = np.zeros((n_epochs,), dtype=np.float32)
    ts_acc_hist = np.zeros((n_epochs), dtype=np.float32)

    for epoch in range(n_epochs):
        print(f'*** EPOCH {epoch} ***')
        print(f'lr: {scheduler.get_last_lr()[0]}')
        tr_loss = 0.
        model.train(mode=True)
        for i in range(batch_per_epoch):
            st = i * BATCH_SIZE
            X_batch = X_train[st:st + BATCH_SIZE]
            y_batch = y_train[st:st + BATCH_SIZE]
            # Reset gradients
            optimizer.zero_grad()
            
            # predict / forward pass
            y_logits = model(X_batch)
            loss = loss_fn(y_logits, y_batch.to(torch.uint8))
            tr_loss += loss
            # tune / backward pass
            loss.backward()
            
            # update weights
            optimizer.step()
        scheduler.step()
        tr_loss /= batch_per_epoch
        optimizer.zero_grad()
        # test
        with torch.no_grad():
            y_pred_logits = model(X_test)
            acc = accuracy_score(torch.Tensor.cpu(y_test), np.argmax(torch.Tensor.cpu(y_pred_logits), axis=1))
            test_loss = loss_fn(y_pred_logits, y_test.to(torch.uint8))
        
        print("Train Loss {:.2f}".format(tr_loss))
        print("Test Loss {:.2f}".format(test_loss))
        print("Test Accuracy {:.2f} \n".format(acc))
        tr_loss_hist[epoch] = tr_loss
        ts_loss_hist[epoch] = test_loss
        ts_acc_hist[epoch] = acc
    return tr_loss_hist, ts_loss_hist, ts_acc_hist

# %%
model = setup_model(num_classes=NUM_LABELS)
model = model.to(device)
print(model)
# Out:
# Sequential(
#   (0): Embedding(400000, 100)
#   (1): Flatten(start_dim=1, end_dim=-1)
#   (2): Linear(in_features=6400, out_features=2048, bias=True)
#   (3): Dropout(p=0.3, inplace=False)
#   (4): LeakyReLU(negative_slope=0.01)
#   (5): Linear(in_features=2048, out_features=512, bias=True)
#   (6): Dropout(p=0.3, inplace=False)
#   (7): LeakyReLU(negative_slope=0.01)
#   (8): Linear(in_features=512, out_features=64, bias=True)
#   (9): LeakyReLU(negative_slope=0.01)
#   (10): Linear(in_features=64, out_features=5, bias=True)
#   (11): Softmax(dim=1)
# )

# %%
tr_loss_hist, ts_loss_hist, ts_acc_hist = train_model(model, train_emb_ids, test_emb_ids, y_train, y_test, n_epochs=300)
# Out:
# *** EPOCH 0 ***
# lr: 0.001
# Train Loss 1.61
# Test Loss 1.60
# Test Accuracy 0.24
#
# *** EPOCH 1 ***
# lr: 0.001
# Train Loss 1.59
# Test Loss 1.60
# Test Accuracy 0.16
#
# *** EPOCH 2 ***
# lr: 0.001
# Train Loss 1.61
# Test Loss 1.65
# Test Accuracy 0.35
#
# *** EPOCH 3 ***
# lr: 0.001
# Train Loss 1.62
# Test Loss 1.64
# Test Accuracy 0.09
#
# *** EPOCH 4 ***
# lr: 0.001
# Train Loss 1.62
# Test Loss 1.62
# Test Accuracy 0.32
#
# *** EPOCH 5 ***
# lr: 0.001
# Train Loss 1.59
# Test Loss 1.59
# Test Accuracy 0.15
#
# *** EPOCH 6 ***
# lr: 0.001
# Train Loss 1.56
# Test Loss 1.57
# Test Accuracy 0.09
#
# *** EPOCH 7 ***
# lr: 0.001
# Train Loss 1.54
# Test Loss 1.57
# Test Accuracy 0.16
#
# *** EPOCH 8 ***
# lr: 0.001
# Train Loss 1.51
# Test Loss 1.55
# Test Accuracy 0.16
#
# *** EPOCH 9 ***
# lr: 0.001
# Train Loss 1.49
# Test Loss 1.54
# Test Accuracy 0.31
#
# *** EPOCH 10 ***
# lr: 0.001
# Train Loss 1.46
# Test Loss 1.50
# Test Accuracy 0.25
#
# *** EPOCH 11 ***
# lr: 0.001
# Train Loss 1.44
# Test Loss 1.51
# Test Accuracy 0.35
#
# *** EPOCH 12 ***
# lr: 0.001
# Train Loss 1.41
# Test Loss 1.50
# Test Accuracy 0.28
#
# *** EPOCH 13 ***
# lr: 0.001
# Train Loss 1.39
# Test Loss 1.49
# Test Accuracy 0.41
#
# *** EPOCH 14 ***
# lr: 0.001
# Train Loss 1.38
# Test Loss 1.47
# Test Accuracy 0.36
#
# *** EPOCH 15 ***
# lr: 0.001
# Train Loss 1.37
# Test Loss 1.50
# Test Accuracy 0.42
#
# *** EPOCH 16 ***
# lr: 0.001
# Train Loss 1.35
# Test Loss 1.46
# Test Accuracy 0.43
#
# *** EPOCH 17 ***
# lr: 0.001
# Train Loss 1.34
# Test Loss 1.49
# Test Accuracy 0.49
#
# *** EPOCH 18 ***
# lr: 0.001
# Train Loss 1.33
# Test Loss 1.47
# Test Accuracy 0.45
#
# *** EPOCH 19 ***
# lr: 0.001
# Train Loss 1.31
# Test Loss 1.46
# Test Accuracy 0.47
#
# *** EPOCH 20 ***
# lr: 0.001
# Train Loss 1.30
# Test Loss 1.49
# Test Accuracy 0.52
#
# *** EPOCH 21 ***
# lr: 0.001
# Train Loss 1.30
# Test Loss 1.47
# Test Accuracy 0.51
#
# *** EPOCH 22 ***
# lr: 0.001
# Train Loss 1.28
# Test Loss 1.48
# Test Accuracy 0.44
#
# *** EPOCH 23 ***
# lr: 0.001
# Train Loss 1.29
# Test Loss 1.46
# Test Accuracy 0.50
#
# *** EPOCH 24 ***
# lr: 0.001
# Train Loss 1.27
# Test Loss 1.48
# Test Accuracy 0.53
#
# *** EPOCH 25 ***
# lr: 0.001
# Train Loss 1.26
# Test Loss 1.47
# Test Accuracy 0.51
#
# *** EPOCH 26 ***
# lr: 0.001
# Train Loss 1.25
# Test Loss 1.48
# Test Accuracy 0.51
#
# *** EPOCH 27 ***
# lr: 0.001
# Train Loss 1.24
# Test Loss 1.47
# Test Accuracy 0.53
#
# *** EPOCH 28 ***
# lr: 0.001
# Train Loss 1.24
# Test Loss 1.46
# Test Accuracy 0.54
#
# *** EPOCH 29 ***
# lr: 0.001
# Train Loss 1.21
# Test Loss 1.42
# Test Accuracy 0.44
#
# *** EPOCH 30 ***
# lr: 0.001
# Train Loss 1.20
# Test Loss 1.43
# Test Accuracy 0.46
#
# *** EPOCH 31 ***
# lr: 0.001
# Train Loss 1.17
# Test Loss 1.43
# Test Accuracy 0.54
#
# *** EPOCH 32 ***
# lr: 0.001
# Train Loss 1.16
# Test Loss 1.42
# Test Accuracy 0.51
#
# *** EPOCH 33 ***
# lr: 0.001
# Train Loss 1.17
# Test Loss 1.41
# Test Accuracy 0.37
#
# *** EPOCH 34 ***
# lr: 0.001
# Train Loss 1.22
# Test Loss 1.48
# Test Accuracy 0.53
#
# *** EPOCH 35 ***
# lr: 0.001
# Train Loss 1.18
# Test Loss 1.44
# Test Accuracy 0.43
#
# *** EPOCH 36 ***
# lr: 0.001
# Train Loss 1.19
# Test Loss 1.43
# Test Accuracy 0.47
#
# *** EPOCH 37 ***
# lr: 0.001
# Train Loss 1.17
# Test Loss 1.42
# Test Accuracy 0.53
#
# *** EPOCH 38 ***
# lr: 0.001
# Train Loss 1.15
# Test Loss 1.44
# Test Accuracy 0.54
#
# *** EPOCH 39 ***
# lr: 0.001
# Train Loss 1.14
# Test Loss 1.41
# Test Accuracy 0.50
#
# *** EPOCH 40 ***
# lr: 0.001
# Train Loss 1.13
# Test Loss 1.42
# Test Accuracy 0.53
#
# *** EPOCH 41 ***
# lr: 0.001
# Train Loss 1.13
# Test Loss 1.41
# Test Accuracy 0.51
#
# *** EPOCH 42 ***
# lr: 0.001
# Train Loss 1.12
# Test Loss 1.41
# Test Accuracy 0.53
#
# *** EPOCH 43 ***
# lr: 0.001
# Train Loss 1.10
# Test Loss 1.45
# Test Accuracy 0.56
#
# *** EPOCH 44 ***
# lr: 0.001
# Train Loss 1.11
# Test Loss 1.39
# Test Accuracy 0.50
#
# *** EPOCH 45 ***
# lr: 0.001
# Train Loss 1.10
# Test Loss 1.44
# Test Accuracy 0.55
#
# *** EPOCH 46 ***
# lr: 0.001
# Train Loss 1.08
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 47 ***
# lr: 0.001
# Train Loss 1.08
# Test Loss 1.41
# Test Accuracy 0.51
#
# *** EPOCH 48 ***
# lr: 0.001
# Train Loss 1.07
# Test Loss 1.43
# Test Accuracy 0.56
#
# *** EPOCH 49 ***
# lr: 0.001
# Train Loss 1.07
# Test Loss 1.43
# Test Accuracy 0.56
#
# *** EPOCH 50 ***
# lr: 0.001
# Train Loss 1.06
# Test Loss 1.41
# Test Accuracy 0.53
#
# *** EPOCH 51 ***
# lr: 0.001
# Train Loss 1.06
# Test Loss 1.44
# Test Accuracy 0.55
#
# *** EPOCH 52 ***
# lr: 0.001
# Train Loss 1.05
# Test Loss 1.44
# Test Accuracy 0.55
#
# *** EPOCH 53 ***
# lr: 0.001
# Train Loss 1.05
# Test Loss 1.43
# Test Accuracy 0.55
#
# *** EPOCH 54 ***
# lr: 0.001
# Train Loss 1.05
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 55 ***
# lr: 0.001
# Train Loss 1.04
# Test Loss 1.43
# Test Accuracy 0.56
#
# *** EPOCH 56 ***
# lr: 0.001
# Train Loss 1.03
# Test Loss 1.43
# Test Accuracy 0.55
#
# *** EPOCH 57 ***
# lr: 0.001
# Train Loss 1.03
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 58 ***
# lr: 0.001
# Train Loss 1.03
# Test Loss 1.43
# Test Accuracy 0.56
#
# *** EPOCH 59 ***
# lr: 0.001
# Train Loss 1.02
# Test Loss 1.43
# Test Accuracy 0.56
#
# *** EPOCH 60 ***
# lr: 0.001
# Train Loss 1.02
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 61 ***
# lr: 0.001
# Train Loss 1.02
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 62 ***
# lr: 0.001
# Train Loss 1.01
# Test Loss 1.44
# Test Accuracy 0.55
#
# *** EPOCH 63 ***
# lr: 0.001
# Train Loss 1.01
# Test Loss 1.43
# Test Accuracy 0.57
#
# *** EPOCH 64 ***
# lr: 0.001
# Train Loss 1.01
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 65 ***
# lr: 0.001
# Train Loss 1.01
# Test Loss 1.43
# Test Accuracy 0.56
#
# *** EPOCH 66 ***
# lr: 0.001
# Train Loss 1.00
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 67 ***
# lr: 0.001
# Train Loss 1.00
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 68 ***
# lr: 0.001
# Train Loss 1.00
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 69 ***
# lr: 0.001
# Train Loss 1.00
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 70 ***
# lr: 0.001
# Train Loss 1.00
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 71 ***
# lr: 0.001
# Train Loss 1.00
# Test Loss 1.43
# Test Accuracy 0.56
#
# *** EPOCH 72 ***
# lr: 0.001
# Train Loss 1.00
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 73 ***
# lr: 0.001
# Train Loss 1.00
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 74 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 75 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 76 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 77 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 78 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 79 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 80 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 81 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 82 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 83 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 84 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 85 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 86 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 87 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 88 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 89 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 90 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 91 ***
# lr: 0.001
# Train Loss 0.99
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 92 ***
# lr: 0.001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 93 ***
# lr: 0.001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 94 ***
# lr: 0.001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 95 ***
# lr: 0.001
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 96 ***
# lr: 0.001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 97 ***
# lr: 0.001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 98 ***
# lr: 0.001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 99 ***
# lr: 0.001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.58
#
# *** EPOCH 100 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 101 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 102 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 103 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 104 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 105 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 106 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 107 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 108 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 109 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 110 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 111 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 112 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 113 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 114 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 115 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 116 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 117 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 118 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 119 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 120 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 121 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 122 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 123 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 124 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 125 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 126 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 127 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 128 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 129 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 130 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 131 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 132 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 133 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 134 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 135 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 136 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 137 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 138 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 139 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 140 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 141 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 142 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 143 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 144 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 145 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 146 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 147 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 148 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 149 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 150 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 151 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 152 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 153 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 154 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 155 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 156 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 157 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 158 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 159 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 160 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 161 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 162 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 163 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 164 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 165 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 166 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 167 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 168 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 169 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 170 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 171 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 172 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 173 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 174 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 175 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 176 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 177 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 178 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 179 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 180 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 181 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.56
#
# *** EPOCH 182 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 183 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 184 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 185 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 186 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 187 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 188 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 189 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 190 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 191 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 192 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.56
#
# *** EPOCH 193 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 194 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 195 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 196 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 197 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 198 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 199 ***
# lr: 0.0001
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 200 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 201 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 202 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 203 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 204 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 205 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 206 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 207 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 208 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 209 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 210 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 211 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 212 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 213 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 214 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 215 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 216 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 217 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 218 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 219 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 220 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.56
#
# *** EPOCH 221 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 222 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 223 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 224 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 225 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 226 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 227 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 228 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 229 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 230 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 231 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 232 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 233 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 234 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 235 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 236 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 237 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 238 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 239 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 240 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 241 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 242 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 243 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 244 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 245 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 246 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 247 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 248 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 249 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 250 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 251 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 252 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 253 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 254 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 255 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 256 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 257 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 258 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 259 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 260 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 261 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 262 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 263 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 264 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 265 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 266 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 267 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 268 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 269 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.45
# Test Accuracy 0.57
#
# *** EPOCH 270 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 271 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 272 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 273 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 274 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 275 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 276 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 277 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 278 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 279 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 280 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 281 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 282 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 283 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 284 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 285 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 286 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 287 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 288 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 289 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 290 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 291 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 292 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 293 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 294 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 295 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.56
#
# *** EPOCH 296 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 297 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 298 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57
#
# *** EPOCH 299 ***
# lr: 1e-05
# Train Loss 0.98
# Test Loss 1.44
# Test Accuracy 0.57

# %%
MODEL_NAME = "2048_final_ep_300"
torch.save(model, f"./models/{MODEL_NAME}")

# %%
training_hist = pd.DataFrame.from_dict({'train_loss': tr_loss_hist, 'test_loss': ts_loss_hist, 'accuracy': ts_acc_hist})
training_hist.to_csv(f'./models/{MODEL_NAME + '_training_history'}.csv')

# %% [markdown]
# ## Evaluate

# %%
with torch.no_grad():
    y_pred = np.argmax(torch.Tensor.cpu(model(test_emb_ids)), axis=1)
    print(classification_report(torch.Tensor.cpu(y_test), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.11      0.16        94
#          1.0       0.50      0.52      0.51      1089
#          2.0       0.59      0.56      0.57      3004
#          3.0       0.60      0.64      0.62      2492
#          4.0       0.43      0.42      0.43       473
#
#     accuracy                           0.57      7152
#    macro avg       0.48      0.45      0.46      7152
# weighted avg       0.56      0.57      0.56      7152
